# %%
from sklearn.datasets import fetch_openml
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
 
# Mengunduh dataset German Credit dari OpenML
X, y = fetch_openml(name='credit-g', version=1, return_X_y=True, as_frame=True)
 
# Konversi target menjadi numerik
le = LabelEncoder()
y = le.fit_transform(y)  # Mengubah 'good' menjadi 1 dan 'bad' menjadi 0
 
# Melakukan One-Hot Encoding pada fitur kategorikal
X_encoded = pd.get_dummies(X, drop_first=True)  # Konversi fitur kategorikal menjadi numerik
 
# Membagi dataset menjadi training set dan testing set (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42)
 
print("Shape of training data:", X_train.shape)
print("Shape of testing data:", X_test.shape)
# Out:
# Shape of training data: (700, 48)
# Shape of testing data: (300, 48)

# %%
from sklearn.ensemble import RandomForestClassifier
 
# Inisialisasi model Random Forest tanpa hyperparameter tuning
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
 
# Evaluasi awal model tanpa tuning
initial_score = rf.score(X_test, y_test)
print(f"Initial accuracy on test set (without tuning): {initial_score:.2f}")
# Out:
# Initial accuracy on test set (without tuning): 0.76

# %%
from sklearn.model_selection import GridSearchCV
 
# Definisikan parameter grid untuk Grid Search
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}
 
# Inisialisasi GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
 
# Output hasil terbaik
print(f"Best parameters (Grid Search): {grid_search.best_params_}")
best_rf_grid = grid_search.best_estimator_
 
# Evaluasi performa model pada test set
grid_search_score = best_rf_grid.score(X_test, y_test)
print(f"Accuracy after Grid Search: {grid_search_score:.2f}")
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=300; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=20, min_samples_split=10, n_estimators=300; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=2, n_estimators=300; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=2, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.7s
# Best parameters (Grid Search): {'criterion': 'gini', 'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy after Grid Search: 0.76

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
 
# Definisikan ruang pencarian untuk Random Search
param_dist = {
    'n_estimators': np.linspace(100, 500, 5, dtype=int),
    'max_depth': np.linspace(10, 50, 5, dtype=int),
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}
 
# Inisialisasi RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_dist, n_iter=20, cv=3, n_jobs=-1, verbose=2, random_state=42)
random_search.fit(X_train, y_train)
 
# Output hasil terbaik
print(f"Best parameters (Random Search): {random_search.best_params_}")
best_rf_random = random_search.best_estimator_
 
# Evaluasi performa model pada test set
random_search_score = best_rf_random.score(X_test, y_test)
print(f"Accuracy after Random Search: {random_search_score:.2f}")
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=400; total time=   1.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=50, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500; total time=   1.5s
# [CV] END criterion=gini, max_depth=10, min_samples_split=5, n_estimators=500; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=500; total time=   1.3s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=500; total time=   1.4s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=40, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=500; total time=   1.4s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=10, n_estimators=300; total time=   0.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=10, n_estimators=300; total time=   0.7s
# Best parameters (Random Search): {'n_estimators': np.int64(200), 'min_samples_split': 5, 'max_depth': np.int64(30), 'criterion': 'gini'}
# Accuracy after Random Search: 0.76

# %%
from skopt import BayesSearchCV
 
# Definisikan ruang pencarian untuk Bayesian Optimization
param_space = {
    'n_estimators': (100, 500),
    'max_depth': (10, 50),
    'min_samples_split': (2, 10),
    'criterion': ['gini', 'entropy']
}
 
# Inisialisasi BayesSearchCV
bayes_search = BayesSearchCV(estimator=rf, search_spaces=param_space, n_iter=32, cv=3, n_jobs=-1, verbose=2, random_state=42)
bayes_search.fit(X_train, y_train)
 
# Output hasil terbaik
print(f"Best parameters (Bayesian Optimization): {bayes_search.best_params_}")
best_rf_bayes = bayes_search.best_estimator_
 
# Evaluasi performa model pada test set
bayes_search_score = best_rf_bayes.score(X_test, y_test)
print(f"Accuracy after Bayesian Optimization: {bayes_search_score:.2f}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=39, min_samples_split=9, n_estimators=226; total time=   0.5s
# [CV] END criterion=gini, max_depth=39, min_samples_split=9, n_estimators=226; total time=   0.5s
# [CV] END criterion=gini, max_depth=39, min_samples_split=9, n_estimators=226; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=45, min_samples_split=4, n_estimators=480; total time=   1.1s
# [CV] END criterion=entropy, max_depth=45, min_samples_split=4, n_estimators=480; total time=   1.1s
# [CV] END criterion=entropy, max_depth=45, min_samples_split=4, n_estimators=480; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=47, min_samples_split=3, n_estimators=273; total time=   0.6s
# [CV] END criterion=gini, max_depth=47, min_samples_split=3, n_estimators=273; total time=   0.6s
# [CV] END criterion=gini, max_depth=47, min_samples_split=3, n_estimators=273; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=17, min_samples_split=7, n_estimators=421; total time=   1.0s
# [CV] END criterion=entropy, max_depth=17, min_samples_split=7, n_estimators=421; total time=   1.0s
# [CV] END criterion=entropy, max_depth=17, min_samples_split=7, n_estimators=421; total time=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=28, min_samples_split=6, n_estimators=386; total time=   0.9s
# [CV] END criterion=entropy, max_depth=28, min_samples_split=6, n_estimators=386; total time=   1.0s
# [CV] END criterion=entropy, max_depth=28, min_samples_split=6, n_estimators=386; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=48, min_samples_split=3, n_estimators=175; total time=   0.4s
# [CV] END criterion=entropy, max_depth=48, min_samples_split=3, n_estimators=175; total time=   0.4s
# [CV] END criterion=entropy, max_depth=48, min_samples_split=3, n_estimators=175; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=41, min_samples_split=5, n_estimators=450; total time=   1.1s
# [CV] END criterion=entropy, max_depth=41, min_samples_split=5, n_estimators=450; total time=   1.2s
# [CV] END criterion=entropy, max_depth=41, min_samples_split=5, n_estimators=450; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=47, min_samples_split=6, n_estimators=435; total time=   1.0s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=6, n_estimators=435; total time=   1.0s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=6, n_estimators=435; total time=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=38, min_samples_split=9, n_estimators=266; total time=   0.6s
# [CV] END criterion=entropy, max_depth=38, min_samples_split=9, n_estimators=266; total time=   0.7s
# [CV] END criterion=entropy, max_depth=38, min_samples_split=9, n_estimators=266; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=43, min_samples_split=8, n_estimators=202; total time=   0.5s
# [CV] END criterion=gini, max_depth=43, min_samples_split=8, n_estimators=202; total time=   0.6s
# [CV] END criterion=gini, max_depth=43, min_samples_split=8, n_estimators=202; total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=47, min_samples_split=2, n_estimators=210; total time=   0.5s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=2, n_estimators=210; total time=   0.5s
# [CV] END criterion=entropy, max_depth=47, min_samples_split=2, n_estimators=210; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=48, min_samples_split=10, n_estimators=474; total time=   1.1s
# [CV] END criterion=gini, max_depth=48, min_samples_split=10, n_estimators=474; total time=   1.1s
# [CV] END criterion=gini, max_depth=48, min_samples_split=10, n_estimators=474; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=49, min_samples_split=2, n_estimators=126; total time=   0.3s
# [CV] END criterion=entropy, max_depth=49, min_samples_split=2, n_estimators=126; total time=   0.3s
# [CV] END criterion=entropy, max_depth=49, min_samples_split=2, n_estimators=126; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=454; total time=   1.0s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=454; total time=   1.0s
# [CV] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=454; total time=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=46, min_samples_split=10, n_estimators=499; total time=   1.1s
# [CV] END criterion=entropy, max_depth=46, min_samples_split=10, n_estimators=499; total time=   1.1s
# [CV] END criterion=entropy, max_depth=46, min_samples_split=10, n_estimators=499; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=16, min_samples_split=3, n_estimators=107; total time=   0.3s
# [CV] END criterion=gini, max_depth=16, min_samples_split=3, n_estimators=107; total time=   0.4s
# [CV] END criterion=gini, max_depth=16, min_samples_split=3, n_estimators=107; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=18, min_samples_split=8, n_estimators=442; total time=   1.2s
# [CV] END criterion=entropy, max_depth=18, min_samples_split=8, n_estimators=442; total time=   1.1s
# [CV] END criterion=entropy, max_depth=18, min_samples_split=8, n_estimators=442; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=37, min_samples_split=9, n_estimators=258; total time=   0.7s
# [CV] END criterion=entropy, max_depth=37, min_samples_split=9, n_estimators=258; total time=   0.6s
# [CV] END criterion=entropy, max_depth=37, min_samples_split=9, n_estimators=258; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=369; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=369; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5, n_estimators=369; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=10, min_samples_split=9, n_estimators=145; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, min_samples_split=9, n_estimators=145; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, min_samples_split=9, n_estimators=145; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=10, min_samples_split=3, n_estimators=114; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=3, n_estimators=114; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=3, n_estimators=114; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=25, min_samples_split=5, n_estimators=412; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, min_samples_split=5, n_estimators=412; total time=   1.1s
# [CV] END criterion=entropy, max_depth=25, min_samples_split=5, n_estimators=412; total time=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=419; total time=   1.1s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=419; total time=   1.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=5, n_estimators=419; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=444; total time=   1.1s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=444; total time=   1.2s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=444; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=6, n_estimators=107; total time=   0.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=6, n_estimators=107; total time=   0.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=6, n_estimators=107; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=10, min_samples_split=4, n_estimators=153; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=4, n_estimators=153; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=4, n_estimators=153; total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=12, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=12, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=12, min_samples_split=10, n_estimators=100; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=11, min_samples_split=5, n_estimators=500; total time=   1.1s
# [CV] END criterion=gini, max_depth=11, min_samples_split=5, n_estimators=500; total time=   1.2s
# [CV] END criterion=gini, max_depth=11, min_samples_split=5, n_estimators=500; total time=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=4, n_estimators=395; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=4, n_estimators=395; total time=   0.9s
# [CV] END criterion=gini, max_depth=50, min_samples_split=4, n_estimators=395; total time=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=50, min_samples_split=10, n_estimators=100; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=123; total time=   0.3s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=123; total time=   0.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=123; total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END criterion=entropy, max_depth=14, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END criterion=entropy, max_depth=14, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END criterion=entropy, max_depth=14, min_samples_split=2, n_estimators=500; total time=   1.2s
# Best parameters (Bayesian Optimization): OrderedDict([('criterion', 'entropy'), ('max_depth', 10), ('min_samples_split', 5), ('n_estimators', 369)])
# Accuracy after Bayesian Optimization: 0.75
